# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %% [markdown]
# # Part 1: Data Preprocessing

# %%
data = pd.read_csv('Netflix_Userbase.csv')
print("Dataset Structure:")
print(data.head())
print("Dataset shape:", data.shape)

# %% [markdown]
# Missing Values

# %%
print("\nMissing Values:")
print(data.isnull().sum())
# Out:
# Missing Values:
# User ID              0
# Subscription Type    0
# Monthly Revenue      0
# Join Date            0
# Last Payment Date    0
# Country              0
# Age                  0
# Gender               0
# Device               0
# Plan Duration        0
# dtype: int64

# %%
data.fillna(data.mean(), inplace=True)
print("\nCategorical Variables:")
print(data.select_dtypes(include=['object']).columns)
data_encoded = pd.get_dummies(data, drop_first=True)
# Out:
# Categorical Variables:
# Index(['Subscription Type', 'Join Date', 'Last Payment Date', 'Country',
#        'Gender', 'Device', 'Plan Duration'],
#       dtype='object')
# <ipython-input-45-1c2ed1a5d1ba>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.fillna(data.mean(), inplace=True)

# %%
selected_features = ['feature1', 'feature2', 'feature3']
X = data_encoded[selected_features]
y = data_encoded['Monthly_Revenue']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-e7e3e8b83a9f> in <cell line: 2>()
#       1 selected_features = ['feature1', 'feature2', 'feature3']
# ----> 2 X = data_encoded[selected_features]
#       3 y = data_encoded['Monthly_Revenue']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
# ...

# %%
final_data = data_encoded[relevant_features]

# %%
X = final_data.drop(target_variable, axis=1)
y = final_data[target_variable]

# %% [markdown]
# # Descriptive Statistics

# %%
print("Descriptive Statistics:")
print(final_data.describe())
# Out:
# Descriptive Statistics:
#           User ID
# count  2500.00000
# mean   1250.50000
# std     721.83216
# min       1.00000
# 25%     625.75000
# 50%    1250.50000
# 75%    1875.25000
# max    2500.00000

# %% [markdown]
# # Visualizations

# %%
print("Column names in final_data:")
print(final_data.columns)
# Out:
# Column names in final_data:
# Index(['User ID'], dtype='object')

# %%
# Visualize distribution of Subscription Type
plt.figure(figsize=(10, 6))
sns.countplot(data=final_data, x='Subscription Type')
plt.title('Distribution of Subscription Type')
plt.xlabel('Subscription Type')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-7345b31d3e51> in <cell line: 3>()
#       1 # Visualize distribution of Subscription Type
#       2 plt.figure(figsize=(10, 6))
# ----> 3 sns.countplot(data=final_data, x='Subscription Type')
#       4 plt.title('Distribution of Subscription Type')
#       5 plt.xlabel('Subscription Type')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628         raise TypeError("Cannot pass values for both `x` and `y`.")
#    2629
# -> 2630     p = _CategoricalAggPlotter(
#    2631         data=data,
#    2632         variables=dict(x=x, y=y, hue=hue),
#
# ...
